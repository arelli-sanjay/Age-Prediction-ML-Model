# %% [markdown]
# ### Importing Libraries

# %%
import numpy as np 
import pandas as pd

# %%
dataset = pd.read_excel('age_detection_dataset.xlsx')

# %%
dataset
# Out:
#      Height(cm)  Weight(kg)  Gender  Age
# 0           168          71       1   19
# 1           181          44       0   19
# 2           158          44       1   10
# 3           144          53       1   15
# 4           172          51       1   19
# ..          ...         ...     ...  ...
# 995         132          86       1   17
# 996         182          63       1   17
# 997         152          83       1   21
# 998         166          63       0   19
# 999         182          87       0   20
#
# [1000 rows x 4 columns]

# %%
x = dataset.iloc[:,:-1]
y = dataset.iloc[:,-1]

# %%
x
# Out:
#      Height(cm)  Weight(kg)  Gender
# 0           168          71       1
# 1           181          44       0
# 2           158          44       1
# 3           144          53       1
# 4           172          51       1
# ..          ...         ...     ...
# 995         132          86       1
# 996         182          63       1
# 997         152          83       1
# 998         166          63       0
# 999         182          87       0
#
# [1000 rows x 3 columns]

# %%
y
# Out:
# 0      19
# 1      19
# 2      10
# 3      15
# 4      19
#        ..
# 995    17
# 996    17
# 997    21
# 998    19
# 999    20
# Name: Age, Length: 1000, dtype: int64

# %% [markdown]
# ### Spliting the Data

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.2,random_state = 42)

# %% [markdown]
# ### Model

# %%
from sklearn.linear_model import LinearRegression

# %%
reg = LinearRegression()

# %%
reg.fit(x_train,y_train)
# Out:
# LinearRegression()

# %% [markdown]
# ### Predict

# %%
y_pred = reg.predict(x_test)

# %%
y_pred[:10,]
# Out:
# array([17.78232567, 20.38683019, 17.41924828, 16.7558149 , 16.15316136,
#        19.161181  , 19.16059458, 17.12924564, 19.42518935, 13.98228099])

# %%
y_test[:10,]
# Out:
# 521    19
# 737    20
# 740    18
# 660    16
# 411    15
# 678    20
# 626    24
# 513    15
# 859    20
# 136    12
# Name: Age, dtype: int64

# %% [markdown]
# ### Regression Matrix and Accuracy

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score

# %%
mean_absolute_error = mean_absolute_error(y_test,y_pred)

# %%
mean_squared_error = mean_squared_error(y_test,y_pred)

# %%
r2_score = r2_score(y_test,y_pred)

# %%
mean_absolute_error
# Out:
# 1.8304193563232942

# %%
mean_squared_error
# Out:
# 5.4712964176540915

# %%
r2_score
# Out:
# 0.6033675742718252

# %% [markdown]
# ### Sample Example To get Age

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
height = int(input("Enter height (cm): "))
weight = int(input("Enter weight (kg): "))
gender = int(input("Enter gender (0 = Male, 1 = Female): "))

new_data = [[height, weight, gender]]
predicted_age = reg.predict(new_data)
print("Predicted Age:", round(predicted_age[0], 2))
# Out:
# Enter height (cm):  150
# Enter weight (kg):  70
# Enter gender (0 = Male, 1 = Female):  0
# Predicted Age: 19.48
